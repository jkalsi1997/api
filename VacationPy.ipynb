# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import os 
import holoviews as hv

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    olonkinbyen  70.9221   -8.7187      2.90        87         100
# 1        1       yulinshi  38.2906  109.7494     11.32        45          95
# 2        2      rio verde  21.9333  -99.9833     29.83        42          85
# 3        3   grootfontein -19.5667   18.1167     24.76        11           0
# 4        4  visakhapatnam  17.6900   83.2093     25.94        53          40
#
#    Wind Speed Country                 Date
# 0        5.08      SJ  2023-10-22 21:31:32
# 1        2.29      CN  2023-10-22 21:31:09
# 2        6.21      MX  2023-10-22 21:31:33
# 3        2.06     NaN  2023-10-22 21:31:33
# 4        3.60      IN  2023-10-22 21:31:33

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )
                           
output_directory = "output_data"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Define the file path for the saved plot
plot_file_path = os.path.join(output_directory, "city_map.html")

# Save the plot to an HTML file
hv.save(city_map, plot_file_path)

# Display the map
city_map

# Display the map
city_map
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1783', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#critera : max temperature lower than 27ºC but higher than 21ºC
        #wind speed less than 4.5m/s
        #zero cloudiness
        
weather_df = city_data_df.loc[(city_data_df["Max Temp"]<27)
                              &(city_data_df["Max Temp"]<21)
                              &(city_data_df["Wind Speed"]<4.5)
                              &(city_data_df["Cloudiness"]0)
                             
                             ]
                               
                             
                            

# Drop any rows with null values
weather_df.dropna()

# Display sample data
weather_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3          3  grootfontein -19.5667   18.1167     24.76        11           0
# 41        41          sfax  34.7406   10.7603     25.08        78           0
# 74        74  saint-pierre -21.3393   55.4781     21.98        68           0
# 94        94        rakops -21.0167   24.3333     25.36        10           0
# 119      119       tindouf  27.6711   -8.1474     24.25        46           0
# 297      297         keren  15.7778   38.4581     21.36        64           0
# 386      386        casper  42.8666 -106.3131     22.12        29           0
# 392      392        callao -12.0667  -77.1500     23.16        68           0
# 485      485        jiwani  25.0500   61.7417     26.50        77           0
# 526      526       awjilah  29.1081   21.2869     25.75        21           0
# 535      535      anderson  34.5334  -82.6499     25.09        37           0
# 555      555          suez  29.9737   32.5263     21.67        90           0
# 575      575         colby  39.3958 -101.0524     22.12        36           0
# 582      582    woolgoolga -30.1106  153.2007     22.93        45           0
#
#      Wind Speed Country                 Date
# 3          2.06     NaN  2023-10-22 21:31:33
# 41         4.12      TN  2023-10-22 21:31:39
# 74         2.06      RE  2023-10-22 21:30:09
# 94         1.83      BW  2023-10-22 21:31:49
# 119        3.09      DZ  2023-10-22 21:31:55
# 297        2.43      ER  2023-10-22 21:32:27
# 386        2.06      US  2023-10-22 21:32:44
# 392        3.60      PE  2023-10-22 21:32:45
# 485        3.57      PK  2023-10-22 21:33:05
# 526        3.20      LY  2023-10-22 21:33:13
# 535        3.60      US  2023-10-22 21:33:15
# 555        3.96      EG  2023-10-22 21:33:19
# 575        2.57      US  2023-10-22 21:33:23
# 582        2.82      AU  2023-10-22 21:33:24

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy() 

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 3    grootfontein     NaN -19.5667   18.1167        11
# 41           sfax      TN  34.7406   10.7603        78
# 74   saint-pierre      RE -21.3393   55.4781        68
# 94         rakops      BW -21.0167   24.3333        10
# 119       tindouf      DZ  27.6711   -8.1474        46
# 297         keren      ER  15.7778   38.4581        64
# 386        casper      US  42.8666 -106.3131        29
# 392        callao      PE -12.0667  -77.1500        68
# 485        jiwani      PK  25.0500   61.7417        77
# 526       awjilah      LY  29.1081   21.2869        21
# 535      anderson      US  34.5334  -82.6499        37
# 555          suez      EG  29.9737   32.5263        90
# 575         colby      US  39.3958 -101.0524        36
# 582    woolgoolga      AU -30.1106  153.2007        45

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {"categories": "accommodation.hotel",
          "apiKey":geoapify_key
         }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] =  f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# grootfontein - nearest hotel: Meteor Travel Inn
# sfax - nearest hotel: دار بية
# saint-pierre - nearest hotel: Tropic Hotel
# rakops - nearest hotel: Rakops River Lodge
# tindouf - nearest hotel: محمد بوسبي
# keren - nearest hotel: Eritrea Hotel قندق إرتريا
# casper - nearest hotel: Days Inn by Wyndham Casper
# callao - nearest hotel: Casa Ronald
# jiwani - nearest hotel: No hotel found
# awjilah - nearest hotel: No hotel found
# anderson - nearest hotel: La Quinta
# suez - nearest hotel: فندق لوسيندا
# colby - nearest hotel: Budget Inn & Suites
# woolgoolga - nearest hotel: Darlington Beach Resort
#              City Country      Lat       Lng  Humidity  \
# 3    grootfontein     NaN -19.5667   18.1167        11
# 41           sfax      TN  34.7406   10.7603        78
# 74   saint-pierre      RE -21.3393   55.4781        68
# 94         rakops      BW -21.0167   24.3333        10
# 119       tindouf      DZ  27.6711   -8.1474        46
# 297         keren      ER  15.7778   38.4581        64
# 386        casper      US  42.8666 -106.3131        29
# 392        callao      PE -12.0667  -77.1500        68
# 485        jiwani      PK  25.0500   61.7417        77
# 526       awjilah      LY  29.1081   21.2869        21
# 535      anderson      US  34.5334  -82.6499        37
# 555          suez      EG  29.9737   32.5263        90
# 575         colby      US  39.3958 -101.0524        36
# 582    woolgoolga      AU -30.1106  153.2007        45
#
#                      Hotel Name
# 3             Meteor Travel Inn
# 41                      دار بية
# 74                 Tropic Hotel
# 94           Rakops River Lodge
# 119                  محمد بوسبي
# 297   Eritrea Hotel قندق إرتريا
# 386  Days Inn by Wyndham Casper
# 392                 Casa Ronald
# 485              No hotel found
# 526              No hotel found
# 535                   La Quinta
# 555                فندق لوسيندا
# 575         Budget Inn & Suites
# 582     Darlington Beach Resort

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )

output_directory = "output_data"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Define the file path for the saved plot
plot_file_path = os.path.join(output_directory, "hotel_map.html")

# Save the plot to an HTML file
hv.save(hotel_map, plot_file_path)


# Display the map
hotel_map
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1956', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
